# %%
import random
for j in range(200):
    name = ""
    length = random.randint(5,8)
    name += chr(random.randint(65,65+25))
    for i in range(int(length)-1):
        name+= chr(random.randint(97,97+25))
    print(name)
# Out:
# Sfzpbs
# Czqkc
# Kmjuxqku
# Evsat
# Amvxqjc
# Xebzjxp
# Nlkjsy
# Bjqdswge
# Qrzvqvv
# Qwfweny
# Frrdps
# Trwshw
# Nlivqmy
# Qvprzhva
# Xmgax
# Ttvqyfh
# Pkpghazd
# Uecrfujc
# Kvkul
# Zhcmsq
# Zfttsq
# Oexplws
# Wnzpbhg
# Kintbp
# Zdwxfkb
# Oerzsrxj
# Myvlaper
# Tzchukv
# Bumurdnm
# Nmbtkzj
# Psmugb
# Atkal
# Ittggj
# Fhnsegqr
# Wedktckr
# Kiequfj
# Vukaxkjh
# Bvgzy
# Ctrwx
# Vfbmtgf
# Hezpwjm
# Yoifk
# Evmwnzq
# Ogdkhw
# Jkmilqs
# Orqgdoa
# Ubxidtgr
# Dedayoez
# Yentkrsh
# Xkbgox
# Dfbuin
# Qiilfglv
# Glrgnza
# Lvmzi
# Nzuuu
# Gcgdatbo
# Exmtav
# Rnsjrynd
# Jnixvow
# Crffzlmv
# Dagep
# Jvpiwnp
# Qugcsai
# Xades
# Gdvsbsb
# Mrooqfwx
# Cgcnnhca
# Nmgaponx
# Fbccupya
# Cykrta
# Kfpelu
# Fzhxeh
# Fbxhldf
# Myhheh
# Elkyj
# Wivsb
# Xmkzxuhj
# Lesven
# Okeuj
# Xmano
# Sfpgoqij
# Nfhzut
# Xxipgf
# Jiohyah
# Bjiowtln
# Cqnfwj
# Shdsnx
# Toiqape
# Utysp
# Vqnlsj
# Qmoqqhj
# Vxnqzgs
# Cinpru
# Hritc
# Euanzs
# Jgslblbb
# Nduwbr
# Rjhvx
# Jujbdj
# Duprt
# Hbqvuic
# Movqsare
# Eydiux
# Mknyfctv
# ...

# %%
print(chr(97))
# Out:
# a
